# %% [markdown]
# <a href="https://colab.research.google.com/github/J-o-y-y/Fintech_data_analysis/blob/main/%EC%84%A0%ED%98%95_%ED%9A%8C%EA%B7%80_%EB%AA%A8%EB%8D%B8%EC%9D%84_%EC%82%AC%EC%9A%A9%ED%95%9C_%EC%98%88%EC%B8%A1_%EC%8B%A4%EC%8A%B5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# x = np.array([2,0],[4,5],[6,3],[8,5],[10,7])
# y = np.array([20,24,37,40,50])
# '[5,7]'값 예측

# %%
import numpy as np
import tensorflow as tf

# %%
# 학습 데이터
x = np.array([[2, 0], [4, 5], [6, 3], [8, 5], [10, 7]])
y = np.array([20, 24, 37, 40, 50])

# 텐서플로우 모델 생성
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)), # 입력 레이어
    tf.keras.layers.Dense(units=1)     # 출력 레이어
])

# 모델 컴파일
model.compile(optimizer='sgd', loss='mean_squared_error')

# 모델 학습
model.fit(x, y, epochs=1000, verbose=0)

# 예측을 위해 새로운 데이터 입력
new_data = np.array([[5, 7]])

# 예측
prediction = model.predict(new_data)

print("예측값:", prediction[0][0])
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 예측값: 26.128252
